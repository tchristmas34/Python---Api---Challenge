# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import csv
import json
import config as key

# Import API keys
from api_keys import weather_api_key

#weather information
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Load in city data
city_df = pd.read_csv("output_data/cities.csv")
city_random = city_df.sample(500)
cities = city_random["City"].tolist()
#print(cities)

# %%
# Request Weather Info
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Create Lists to Store Data
town = []
lat = []
lon = []
temp = []
hum = []
cloud = []
wind = []

for city in cities:
    print(f"Proccessing Record {city}")
    
    response = requests.get(url + city + "&units=imperial&appid=" + weather_api_key).json()
    
    try:
        town.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        
    except KeyError:
        print("Nada")
# Out:
# Proccessing Record narok
# Proccessing Record puerto ayora
# Proccessing Record nanortalik
# Proccessing Record bambous virieux
# Proccessing Record necochea
# Proccessing Record zyryanovsk
# Proccessing Record alice springs
# Proccessing Record carnarvon
# Proccessing Record ilulissat
# Proccessing Record nioro
# Proccessing Record mount gambier
# Proccessing Record raglan
# Proccessing Record sitka
# Proccessing Record san cristobal
# Proccessing Record zaraza
# Proccessing Record kvarkeno
# Proccessing Record hami
# Proccessing Record jamestown
# Proccessing Record wajima
# Proccessing Record edd
# Proccessing Record sinnamary
# Proccessing Record rio gallegos
# Proccessing Record bonito
# Proccessing Record juiz de fora
# Proccessing Record noumea
# Proccessing Record pontes e lacerda
# Proccessing Record khash
# Proccessing Record tam ky
# Proccessing Record altagracia de orituco
# Proccessing Record shalinskoye
# Proccessing Record talcahuano
# Proccessing Record alyangula
# Proccessing Record kodiak
# Proccessing Record le port
# Proccessing Record geraldton
# Proccessing Record baruun-urt
# Proccessing Record tagusao
# Proccessing Record hamilton
# Proccessing Record russkiy aktash
# Proccessing Record vitim
# Proccessing Record talmenka
# Proccessing Record najran
# Proccessing Record cayenne
# Proccessing Record lebu
# Proccessing Record gunjur
# Proccessing Record aykhal
# Proccessing Record xam nua
# Proccessing Record dikson
# Proccessing Record marawi
# Proccessing Record horta
# Proccessing Record bjornevatn
# Proccessing Record tutoia
# Proccessing Record iqaluit
# Proccessing Record medicine hat
# Proccessing Record grand baie
# Proccessing Record pacific grove
# Proccessing Record brainerd
# Proccessing Record raymond
# Proccessing Record rocha
# Proccessing Record wawa
# Proccessing Record port hardy
# Proccessing Record lavrentiya
# Proccessing Record daru
# Proccessing Record mogok
# Proccessing Record banfora
# Proccessing Record manzhouli
# Proccessing Record torbay
# Proccessing Record margate
# Proccessing Record arman
# Proccessing Record port shepstone
# Proccessing Record paamiut
# Proccessing Record manado
# Proccessing Record ponta do sol
# Proccessing Record russkaya polyana
# Proccessing Record forio
# Proccessing Record meulaboh
# Proccessing Record keflavik
# Proccessing Record natchez
# Proccessing Record murray bridge
# Proccessing Record rabo de peixe
# Proccessing Record manama
# Proccessing Record bandarbeyla
# Proccessing Record bundaberg
# Proccessing Record waipawa
# Proccessing Record santa ines
# Proccessing Record cobija
# Proccessing Record tigil
# Proccessing Record bathsheba
# Proccessing Record adrar
# Proccessing Record khor
# Proccessing Record san ramon
# Proccessing Record coquimbo
# Proccessing Record prainha
# Proccessing Record hulan ergi
# Proccessing Record tocopilla
# Proccessing Record banjar
# Proccessing Record shebalino
# Proccessing Record hare bay
# Proccessing Record loukhi
# Proccessing Record la seyne-sur-mer
# Proccessing Record half moon bay
# Proccessing Record tuktoyaktuk
# Proccessing Record kolyvan
# Proccessing Record marzuq
# Proccessing Record fuxin
# Proccessing Record oranjestad
# Proccessing Record andradas
# Proccessing Record bredasdorp
# Proccessing Record mikkeli
# Proccessing Record loikaw
# Proccessing Record namatanai
# Proccessing Record slave lake
# Proccessing Record oga
# Proccessing Record kargasok
# Proccessing Record san rafael del sur
# Proccessing Record deputatskiy
# Proccessing Record castro
# Proccessing Record haines junction
# Proccessing Record zhuhai
# Proccessing Record saskylakh
# Proccessing Record hermanus
# Proccessing Record doha
# Proccessing Record avera
# Proccessing Record port blair
# Proccessing Record melfi
# Proccessing Record kokstad
# Proccessing Record saint-denis
# Proccessing Record kavieng
# Proccessing Record motygino
# Proccessing Record thanatpin
# Proccessing Record high rock
# Proccessing Record mocuba
# Proccessing Record leningradskiy
# Proccessing Record lagos
# Proccessing Record ganzhou
# Proccessing Record mizan teferi
# Proccessing Record san juan del sur
# Proccessing Record jalu
# Proccessing Record provideniya
# Proccessing Record malindi
# Proccessing Record ogbomosho
# Proccessing Record hasaki
# Proccessing Record bontang
# Proccessing Record quanzhou
# Proccessing Record east london
# Proccessing Record straumen
# Proccessing Record nador
# Proccessing Record qaanaaq
# Proccessing Record zhezkazgan
# Proccessing Record taybad
# Proccessing Record mamakan
# Proccessing Record brae
# Proccessing Record san-pedro
# Proccessing Record ayan
# Proccessing Record ketchikan
# Proccessing Record saint-georges
# Proccessing Record aklavik
# Proccessing Record qasigiannguit
# Proccessing Record antsohihy
# Proccessing Record georgetown
# Proccessing Record valenca do piaui
# Proccessing Record denpasar
# Proccessing Record airai
# Proccessing Record high prairie
# Proccessing Record chuy
# Proccessing Record pasni
# Proccessing Record byron bay
# Proccessing Record sorong
# Proccessing Record vung tau
# Proccessing Record road town
# Proccessing Record ribeira grande
# Proccessing Record mount isa
# Proccessing Record leh
# Proccessing Record burnie
# Proccessing Record ekimchan
# Proccessing Record auki
# Proccessing Record launceston
# Proccessing Record kantang
# Proccessing Record atar
# Proccessing Record boyolangu
# Proccessing Record bonavista
# Proccessing Record vila do maio
# Proccessing Record union
# Proccessing Record trapani
# Proccessing Record anan
# Proccessing Record paraiso
# Proccessing Record christchurch
# Proccessing Record varhaug
# Proccessing Record ostrovnoy
# Proccessing Record svodin
# Proccessing Record syumsi
# Proccessing Record kruisfontein
# Proccessing Record thinadhoo
# Proccessing Record le marin
# Proccessing Record yumen
# Proccessing Record kaitangata
# Proccessing Record henties bay
# Proccessing Record kayseri
# Proccessing Record souillac
# Proccessing Record gobabis
# Proccessing Record camacha
# Proccessing Record hobart
# Proccessing Record san ramon de la nueva oran
# Proccessing Record esperance
# Proccessing Record salinopolis
# Proccessing Record bilibino
# Proccessing Record ust-barguzin
# Proccessing Record makakilo city
# Proccessing Record betafo
# Proccessing Record pangnirtung
# Proccessing Record hereford
# Proccessing Record plainview
# Proccessing Record pahrump
# Proccessing Record norman wells
# Proccessing Record fort nelson
# Proccessing Record port hedland
# Proccessing Record cockburn town
# Proccessing Record chokurdakh
# Proccessing Record kyren
# Proccessing Record kirkuk
# Proccessing Record san felipe
# Proccessing Record muzhi
# Proccessing Record cooma
# Proccessing Record shimoda
# Proccessing Record tautira
# Proccessing Record viedma
# Proccessing Record wexford
# Proccessing Record raduzhnyy
# Proccessing Record los teques
# Proccessing Record coihaique
# Proccessing Record kununurra
# Proccessing Record carballo
# Proccessing Record qinhuangdao
# Proccessing Record hofn
# Proccessing Record samarinda
# Proccessing Record kizukuri
# Proccessing Record seoul
# Proccessing Record samana
# Proccessing Record hilo
# Proccessing Record okha
# Proccessing Record beisfjord
# Proccessing Record tiarei
# Proccessing Record saldanha
# Proccessing Record westport
# Proccessing Record constitucion
# Proccessing Record russell
# Proccessing Record ingham
# Proccessing Record luderitz
# Proccessing Record buchach
# Proccessing Record kalabo
# Proccessing Record nagua
# Proccessing Record faya
# Proccessing Record atasu
# Proccessing Record sawtell
# Proccessing Record birjand
# Proccessing Record bonfim
# Proccessing Record dudinka
# Proccessing Record mackay
# Proccessing Record chunhuhub
# Proccessing Record onokhoy
# Proccessing Record yakeshi
# Proccessing Record mahebourg
# Proccessing Record balkanabat
# Proccessing Record tabas
# Proccessing Record tshikapa
# Proccessing Record macau
# Proccessing Record lompoc
# Proccessing Record delemont
# Proccessing Record comodoro rivadavia
# Proccessing Record muskegon
# Proccessing Record miraflores
# Proccessing Record acapulco
# Proccessing Record datong
# Proccessing Record iwanai
# Proccessing Record yar-sale
# Proccessing Record dingle
# Proccessing Record sarai mir
# Proccessing Record ishigaki
# Proccessing Record kieta
# Proccessing Record codrington
# Proccessing Record nago
# Proccessing Record zaysan
# Proccessing Record crotone

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Compile and Create DataFrame
weather_dict = {
    "City": town,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature (F)": temp,
    "Humidity (%)": hum,
    "Cloudiness (%)": cloud,
    "Wind Speed (mph)": wind}
weather_data = pd.DataFrame(weather_dict)
weather_data = weather_data.drop_duplicates(subset='City', keep="first")

# Save File to CSV
weather_data.to_csv("output_data/Weather_Data.csv", index=False, header=True)

# Show DataFrame
weather_data
# Out:
#                 City  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0              Narok     -1.08      35.86            54.07            94
# 1       Puerto Ayora     -0.74     -90.35            75.00            90
# 2         Nanortalik     60.14     -45.24            45.27            96
# 3    Bambous Virieux    -20.34      57.76            72.73            78
# 4           Necochea    -38.55     -58.74            48.00            88
# ..               ...       ...        ...              ...           ...
# 495            Kieta     -6.22     155.63            84.42            73
# 496       Codrington    -38.27     141.97            53.76            63
# 497             Nago     26.59     127.98            84.13            83
# 498           Zaysan     47.47      84.87            74.26            39
# 499          Crotone     39.09      17.12            63.72            67
#
#      Cloudiness (%)  Wind Speed (mph)
# 0                46              4.61
# 1                71              1.99
# 2                99              5.01
# 3                75             12.75
# 4               100              3.00
# ..              ...               ...
# 495              18              3.47
# 496              92             10.16
# 497              75             16.11
# 498              16             10.42
# 499              98              3.47
#
# [500 rows x 7 columns]

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# Here we are looking at the difference in temperature based on the latitude. You can see the closer the latitude is to zero, the higher the temperature

# %%
# Scatter Plot Temperature (F) vs. Latitude
    
# Define Variables
x0 = weather_data["Temperature (F)"]
y = weather_data["Latitude"]
N = len(weather_data["City"].value_counts())
colors = np.random.rand(N)

# Create Plot and Labels
plt.scatter(x0, y, c=colors, alpha=0.5)
plt.xlabel("Temperature (F)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Temperature (F)")

# Save Plot as PNG
plt.savefig("output_data/Temp_Lat.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# The higher the latitude you can see an increase in humidity %

# %%
# Scatter Plot Humidity (%) vs. Latitude

# Define New Variables
x1 = weather_data["Humidity (%)"]

# Create Plot and Labels
plt.scatter(x1, y, c=colors, alpha=0.5)
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Humidity (%)")

# Save Plot as PNG
plt.savefig("output_data/Hum_Lat.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# There is no significant trend to cloudiness and latitude.

# %%
# Scatter Plot Cloudiness (%) vs. Latitude

# Define New Variables
x2 = weather_data["Cloudiness (%)"]

# Create Plot and Labels
plt.scatter(x2, y, c=colors, alpha=0.5)
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Cloudiness (%)")

# Save Plot as PNG
plt.savefig("output_data/Cloud_Lat.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# The lower the windspeed the more impactful it is to latitude. Note, latitude has no affect on higher wind speeds.

# %%
# Scatter Plot Wind Speed (mph) vs. Latitude

# Define New Variables
x3 = weather_data["Wind Speed (mph)"]

# Create Plot and Labels
plt.scatter(x3, y, c=colors, alpha=0.5)
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Wind Speed (mph)")

# Save Plot as PNG
plt.savefig("output_data/Wind_Lat.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
north_lat = weather_data[y >= 0]
south_lat = weather_data[y < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
# Northern Hemisphere (With Linear Regression) - Temperature (F) vs Latitude

# Define Variables
l_north = north_lat["Latitude"]
t_north = north_lat["Temperature (F)"]
N = len(north_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(t_north, l_north)
regress_values = t_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(t_north, l_north, c=colors, alpha=0.5)
plt.xlabel("Temperature (F)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Temperature (F)")

# Plot Linear Regression
plt.plot(t_north,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/North_Temp_Lat.png")

# %% [raw]
# For the Lat vs Temp linear regression plot you can obsive the increase in temperature based on the decline of latitude.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere (With Linear Regression) - Temperature (F) vs Latitude

# Define Variables
l_south = south_lat["Latitude"]
t_south = south_lat["Temperature (F)"]
N = len(south_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(t_south, l_south)
regress_values = t_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(t_south, l_south, c=colors, alpha=0.5)
plt.xlabel("Temperature (F)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Temperature (F)")

# Plot Linear Regression
plt.plot(t_south,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/South_Temp_Lat.png")

# %% [markdown]
# The the lat vs temp f you are able to observe an increase of temperature due to an increase of latitude

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere (With Linear Regression) - Humidity (%) vs Latitude

# Define Variables
l_south = south_lat["Latitude"]
h_south = south_lat["Humidity (%)"]
N = len(south_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(h_south, l_south)
regress_values = h_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(h_south, l_south, c=colors, alpha=0.5)
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Humidity (%)")

# Plot Linear Regression
plt.plot(h_south,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/South_Hum_Lat.png")

# %% [markdown]
# In lat vs Hum there is no significant relationship. However, there is some data correlation at 80% humidity and -20 lat.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere (With Linear Regression) - Cloudiness (%) vs Latitude

# Define Variables
l_north = north_lat["Latitude"]
c_north = north_lat["Cloudiness (%)"]
N = len(north_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(c_north, l_north)
regress_values = c_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(c_north, l_north, c=colors, alpha=0.5)
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Cloudiness (%)")

# Plot Linear Regression
plt.plot(c_north,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/North_Cloud_Lat.png")

# %% [markdown]
# In lat vs cloudiness% of positive latitude there is no major correlation to the data.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere (With Linear Regression) - Cloudiness (%) vs Latitude

# Define Variables
l_south = south_lat["Latitude"]
c_south = south_lat["Cloudiness (%)"]
N = len(south_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(c_south, l_south)
regress_values = c_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(c_south, l_south, c=colors, alpha=0.5)
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Cloudiness (%)")

# Plot Linear Regression
plt.plot(c_south,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/South_Cloud_Lat.png")

# %% [markdown]
# In lat vs cloudiness % in negative latitude there is no significant correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere (With Linear Regression) - Wind Speed (mph) vs Latitude

#Define Variables
l_north = north_lat["Latitude"]
w_north = north_lat["Wind Speed (mph)"]
N = len(north_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(w_north, l_north)
regress_values = w_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(w_north, l_north, c=colors, alpha=0.5)
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Wind Speed (mph)")

# Plot Linear Regression
plt.plot(w_north,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/North_Wind_Lat.png")

# %% [markdown]
# In lat vs wind speed there is a correlation between 30 and 40 in event of lower wind speed of 0 - 10

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere (With Linear Regression) - Wind Speed (mph) vs Latitude

#Define Variables
l_south = south_lat["Latitude"]
w_south = south_lat["Wind Speed (mph)"]
N = len(south_lat["City"].value_counts())
colors = np.random.rand(N)

# Optional: Write Function For Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(w_south, l_south)
regress_values = w_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Plot and Labels
plt.scatter(w_south, l_south, c=colors, alpha=0.5)
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.title("Latitude vs. Wind Speed (mph)")

# Plot Linear Regression
plt.plot(w_south,regress_values,"r-")

# Save Plot as PNG
plt.savefig("output_data/South_Wind_Lat.png")

# %% [markdown]
# You can see at 0 mph wind speed there is some correlation to the data - as it increases you are unable to see any significance.
